# %%
import random 
toss=random.choice(["Head","Tail"])
print(toss)
# Out:
# Head

# %%
import numpy as np 
arr=np.array([1,2,3,4,5,6])
prob=len(arr[arr%2==0])/len(arr)
print(prob)
# Out:
# 0.5

# %%
heads=0
tails=0 
for i in range()
