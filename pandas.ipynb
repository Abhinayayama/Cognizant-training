# %%
import pandas as pd 
marks=pd.Series([10,45,76,80])
mark=pd.Series()
print(marks)
print(mark)
print(marks[1])
# Out:
# 0    10
# 1    45
# 2    76
# 3    80
# dtype: int64
# Series([], dtype: object)
# 45

# %%
student_name=pd.Series(["abhinaya","sweety","vyshu"])
print(student_name)
# Out:
# 0    abhinaya
# 1      sweety
# 2       vyshu
# dtype: object

# %%
salary=pd.Series([25000,45000,50000,34000])
print(salary)
# Out:
# 0    25000
# 1    45000
# 2    50000
# 3    34000
# dtype: int64

# %%
t=pd.Series(("abhinaya","sweety","vyshu"))
print(t)
# Out:
# 0    abhinaya
# 1      sweety
# 2       vyshu
# dtype: object

# %%
student={"abhinaya":56,
            "sweety":74,
               "vyshu":89,
         }  
s=pd.Series(student)
print(s)
# Out:
# abhinaya    56
# sweety      74
# vyshu       89
# dtype: int64

# %%
i=pd.Series([100,300,800])
print(i)
# Out:
# 0    100
# 1    300
# 2    800
# dtype: int64

# %%
ci=pd.Series([100,560,789,786],
             index=["a","b","c","d"])
print(ci)
print(ci["d"])
print(ci[["a","c"]])
print(ci.index)
print(ci.values)
print(ci.dtype)
print(ci.size)
# Out:
# a    100
# b    560
# c    789
# d    786
# dtype: int64
# 786
# a    100
# c    789
# dtype: int64
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [100 560 789 786]
# int64
# 4

# %%
import pandas as pd
t=pd.Series((10,20,30))
print(t +10)
print(t *2)
# Out:
# 0    20
# 1    30
# 2    40
# dtype: int64
# 0    20
# 1    40
# 2    60
# dtype: int64
