# %%
import pandas as pd 
orders=pd.Series(["Deliverd","Cancelled","Deliverd","Pending"])
print(orders.dtype)
orders=orders.astype("category")
print(orders.dtype)
# Out:
# object
# category

# %%
import pandas as pd 
orders=pd.Series([1,2,4,6,8])
print(orders.dtype)
orders=orders.astype("category")
print(orders.dtype)
# Out:
# int64
# category

# %%
salary=[10000,45000,32000,50000]
new_salary=[]
for s in salary:
    new_salary.append(s *1.1)
print(new_salary)
# Out:
# [11000.0, 49500.00000000001, 35200.0, 55000.00000000001]

# %%
import numpy as np 
salary=np.array([1000,4000,2000,6000])
new_salary=salary*1.1
print(new_salary)
# Out:
# [1100. 4400. 2200. 6600.]

# %%
prize=np.array([500,400,200,600])
discount=prize*0.5
print(discount)
# Out:
# [250. 200. 100. 300.]

# %%
import pandas as pd
data=pd.Series(range(1,10))
sample=data.sample(4)
print(sample)
# Out:
# 2    3
# 4    5
# 6    7
# 0    1
# dtype: int64

# %%
import pandas as pd
data=pd.Series(range(1,10))
sample=data.sample(frac=0.2)
print(sample)
# Out:
# 1    2
# 0    1
# dtype: int64

# %%
import numpy as np
salary=([20000,50000,70000,40000])
print(np.mean(salary))
# Out:
# 45000.0

# %%
import numpy as np
salary=([20000,50000,70000,40000])
print(np.median(salary))
# Out:
# 45000.0

# %%
from scipy import stats
data=[20,50,70,40]
print(stats.mode(data))
# Out:
# ModeResult(mode=np.int64(20), count=np.int64(1))

# %%
import numpy as np
salary=([54000,60000,34000,10000])
print(np.median(salary))
print(np.max(salary))
print(np.max(salary)-np.min(salary))
print(np.var(salary))
print(np.std(salary))
# Out:
# 44000.0
# 60000
# 50000
# 382750000.0
# 19563.997546513852
