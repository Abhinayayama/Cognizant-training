# %%
def count(n):
    if n==0:
        return
    print(n)
    count(n-1)

count(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def count(n):
    if n==2:
        return
    print(n)
    count(n-1)

count(5)
# Out:
# 5
# 4
# 3

# %%
def count(n):
    if n==2:
        print(n)
        continue
    count(n-1)

count(5)
# Out:
#   Cell In[10], line 4
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
def count(n):
    if n==0:
        return
    print("hi")
    count(n-1)

count(5)
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
def count(n):
    if n==0:
        return 1
    return n*fact(n-1)

print(fact(5(
