# %%
import numpy as np
a=np.array([1,5,8,9])
b=np.array([2,4,3,7])
print(np.hstack((a,b)))
# Out:
# [1 5 8 9 2 4 3 7]

# %%
import numpy as np
a=np.array([1,5,8,9])
b=np.array([2,4,3,7])
print(np.vstack((a,b)))
# Out:
# [[1 5 8 9]
#  [2 4 3 7]]

# %%
arr=np.array([2,5,8,3])
print(arr +5)
# Out:
# [ 7 10 13  8]

# %%
arr=np.array([[2,4,6,],[5,3,6]])
print(arr +[3,8,4])
# Out:
# [[ 5 12 10]
#  [ 8 11 10]]
