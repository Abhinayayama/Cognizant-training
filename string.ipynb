# %%
name = "abhinaya"
print(name)
# Out:
# abhinaya

# %%
city="pune"
print(city[1])
# Out:
# u

# %%
name="abhinaya"
Email="abhinayasaisri@gmail.com"
print(name,Email)
# Out:
# abhinaya abhinayasaisri@gmail.com

# %%
city="karimnagar"
print(city[-1])
# Out:
# r

# %%
name="abhinaya"
print(name[1:4])
# Out:
# bhi

# %%
name="abhinaya"
print(len(name))
# Out:
# 8

# %%
First="abhiaya"
second="yama"
print(First +" "+ second)
# Out:
# abhiaya yama

# %%
print("hello" * 3)
# Out:
# hellohellohello

# %%
print(" hello " * 3)
# Out:
#  hello  hello  hello

# %%
name="abhinaya"
print(name . upper())
# Out:
# ABHINAYA

# %%
name=input ("Enter the name,abhinaya")
print("wellcome",name):
# Out:
#   Cell In[13], line 2
#     print("wellcome",name):
#                           ^
# SyntaxError: invalid syntax
