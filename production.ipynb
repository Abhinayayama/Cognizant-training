# %%
import numpy as np
sales = np.array([120,340,560,230,150])
products = np.array(["A","B","C","D","E"])
print(products[sales>200])
# Out:
# ['B' 'C' 'D']

# %%
print(np.average(sales))
# Out:
# 280.0

# %%
print(np.sort(sales))
# Out:
# [120 150 230 340 560]

# %%
print(np.vstack(sales))
# Out:
# [[120]
#  [340]
#  [560]
#  [230]
#  [150]]

# %%
print(np.hstack(sales))
# Out:
# [120 340 560 230 150]

# %%
print(np.vstack(products))
# Out:
# [['A']
#  ['B']
#  ['C']
#  ['D']
#  ['E']]
