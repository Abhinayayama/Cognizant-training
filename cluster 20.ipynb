# %%
import matplotlib.pyplot as plt
products=["Mobile","Laptop","Tablet"]
sales=[600,200,400]
plt.bar(products,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
students=["bhuchad","hidie","Dora"]
marks=[50,89,49]
plt.bar(students,marks)
plt.show()

# %%
plt.barh(products,sales)
plt.show()

# %%
import numpy as np
products=["mobile","laptop","tablet"]
sales_2024=[200,300,400]
sales_2025=[100,500,600]
X=np.arange(len(products))
width=0.5
plt.bar(X-width/2,sales_2024,width)
plt.bar



(X-width/2,sales_2025,width)
plt.show()

# %%
products=["mobile","laptop","tablet","aba"]
online=[200,300,400,500]
offline=[100,500,400,300]
plt.bar(products,online)
plt.bar(products,offline,bottom=online)
plt.show()

# %%
subject=["maths","physics","chemistry"]
semester_1=[100,00,800]
semester_2=[400,600,900]
plt.bar(subject,semester_1)
plt.bar(subject,semester_2,bottom=semester_1)
# Out:
# <BarContainer object of 3 artists>

# %%
Custumers=list(range(1,200))
k=20
sample=Custumers[::k]
print("Systematic sam;ple:",sample)
# Out:
# Systematic sam;ple: [1, 21, 41, 61, 81, 101, 121, 141, 161, 181]

# %%
import random
developer=list(range(50,100))
tester=list(range(200,400))
manager=list(range(600,900))
sample_dev=random.Sample(developer,5)
sample_test=random.Sample(tester,3)
sample_test=random.Sample(manager,2)
final_sample=sample_dev+sample_test+sample_mrg
print(final_sample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 5
#       3 tester=list(range(200,400))
#       4 manager=list(range(600,900))
# ----> 5 sample_dev=random.Sample(developer,5)
#       6 sample_test=random.Sample(tester,3)
#       7 sample_test=random.Sample(manager,2)
#
# AttributeError: module 'random' has no attribute 'Sample'

# %%
clusters={
          "telangana":[1,3,6,7,8],
          "tamilnadu":[3,8,9,7,6],
          "karala":[4,8,0,7,6]
}
select_clusters=["telangana","karala"]
sample=[]
for cluster in select_clusters:
    sample.extend(clusters[cluster])
    print("cluster sample:",sample)
# Out:
# cluster sample: [1, 3, 6, 7, 8]
# cluster sample: [1, 3, 6, 7, 8, 4, 8, 0, 7, 6]
