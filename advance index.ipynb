# %%
import numpy as np
marks=np.array([56,87,87,54,45,34])
print(marks[marks> 50])
# Out:
# [56 87 87 54]

# %%
marks=np.array([["vyshu",67],["sweety",90]])
print(marks[marks>65])5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 marks=np.array([["vyshu",67],["sweety",90]])
# ----> 2 print(array[marks>65])
#
# NameError: name 'array' is not defined

# %%
arr=np.array([5,6,8,9,6,])
for i in arr:
    print (i)
# Out:
# 5
# 6
# 8
# 9
# 6

# %%
arr=np.array([27,34,56,89])
for i in arr:
    print(i)
# Out:
# 27
# 34
# 56
# 89

# %%
arr=np.array([[34,56],[89,43]])
print (arr)
# Out:
# [[34 56]
#  [89 43]]

# %%
import numpy as np
first=np.array(["abhinaya","nithishma","vyshnavi","sweety"])
print(first[1])
# Out:
# nithishma

# %%
import numpy as np
first=np.array(["abhinaya","nithishma","vyshnavi","sweety"])
print(first[1])
print(first[3])
# Out:
# nithishma
# sweety

# %%
for i in np.nditer(arr):
    print(i)
# Out:
# 5
# 6
# 8
# 9
# 6

# %%
import numpy as np
first=np.array([["sweety","vyshu"],["abhi","vyshu"],["sweety","abhi"]])
print(first[0])
print(first[1])
# Out:
# ['sweety' 'vyshu']
# ['abhi' 'vyshu']

# %%
marks=([45,56,78,89])
for i in np.nditer(marks):
    print(i)
# Out:
# (array(45), array(56), array(78), array(89))

# %%
arr1=([3,5,5,8,9,7])
arr2=([4,4,8,7,6,3])
print(arr1+arr2)
# Out:
# [3, 5, 5, 8, 9, 7, 4, 4, 8, 7, 6, 3]

# %%
arr1=np.array([3,5,5,8,9,7])
arr2=np.array([4,4,8,7,6,3])
print(arr1+arr2)
# Out:
# [ 7  9 13 15 15 10]

# %%
arr1=(['cat','mat','bat','dog'])
arr2=(['dinny','chinny','pinny'])
print(arr1+arr2)
# Out:
# ['cat', 'mat', 'bat', 'dog', 'dinny', 'chinny', 'pinny']

# %%
a=([3,4,5,7])
b=([4,7,9,7])
c=np.concatenate((a,b))
print(c)
# Out:
# [3 4 5 7 4 7 9 7]
