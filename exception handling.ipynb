# %%
try:
    num=int(input("Enter the number"))
    print(10/num)
except ValueError:
    print("Invalid Input")
except ZeroDivisionError:
    print("Cannot divide by zero")
else:
    print("Program execute sucessfully")
# Out:
# Enter the number r
# Invalid Input

# %%
try:
    num=int(input("Enter the number"))
    print(10/num)
except ValueError:
    print("Invalid Input")
except ZeroDivisionError:
    print("Cannot divide by zero")
else:
    print("Program execute sucessfully")
# Out:
# Enter the number 8
# 1.25
# Program execute sucessfully
# This block is going to execute everythime

# %%
age=int(input("Enter the age"))
if age<18:
    raise Exception("you are not Eligible for vote")
print("Eligible")
# Out:
# Enter the age 19
# Eligible
