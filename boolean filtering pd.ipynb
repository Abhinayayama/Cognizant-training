# %%
import pandas as pd
s=pd.Series([20,30,40,50])
print(s.sum())
print(s.max())
print(s.min())
print(s.mean())
# Out:
# 140
# 50
# 20
# 35.0

# %%
s=pd.Series([34,56,77,89,90])
print(s[s>=40])
# Out:
# 1    56
# 2    77
# 3    89
# 4    90
# dtype: int64

# %%
b=pd.Series([3,78,56,99,55,34,23])
print([b>44])
# Out:
# [0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool]
