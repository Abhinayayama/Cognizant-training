# %%
import pandas as pd
present=pd.Series(["abhi","sweety","vyshu"])
absent=pd.Series(["munni","chintu"])
present=present.astype("category")
print(present)
# Out:
# 0      abhi
# 1    sweety
# 2     vyshu
# dtype: category
# Categories (3, object): ['abhi', 'sweety', 'vyshu']

# %%
import numpy as np 
sales=np.array([600,300,500,900,400])
discount=sales*0.5
print(discount)
# Out:
# [300. 150. 250. 450. 200.]

# %%
marks=np.array([90,70,60,40,30])
extra=marks+60
print(extra)
# Out:
# [150 130 120 100  90]
