# %%
import numpy as np
arr=np.array([57,45,90,54,45])
x=np.where(arr==45)
print(x)
# Out:
# (array([1, 4]),)

# %%
import numpy as np
arr=np.array([57,45,90,54,45])
x=np.sort(arr==45)
print(x)
# Out:
# [False False False  True  True]

# %%
import numpy as np
arr=np.array([57,45,90,54,45])
x=np.sort(arr)
print(x)
# Out:
# [45 45 54 57 90]

# %%
import numpy as np
arr1=([2,3,4,5])
arr2=([3,5,6,7])
arr3=np.array((arr1+arr2))
print(arr3)
# Out:
# [2 3 4 5 3 5 6 7]

# %%
arr=np.array([10,20,30,40,50,60])
print(np.sum(arr))
print(np.min(arr))
print(np.max(arr))
print(np.average(arr))
print(np.mean(arr))
# Out:
# 210
# 10
# 60
# 35.0
# 35.0

# %%
print(np.power(arr,2))
# Out:
# [ 100  400  900 1600 2500 3600]

# %%
666666666666666666666666665
